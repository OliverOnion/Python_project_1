# %% [markdown]
# Здесь находится код для проектной работы по компьютерной лингвистике. Цель проекта: проанализировать корпус текстов на немецком языке по тематике "Индустрия 4.0" и извлечь из него список ключевых слов, используя модель tf-idf.

# %% [markdown]
# Шаг 1: загрузка коллекции текстов и сохранение этих текстов в переменные (а также добавление их в список).
# На выходе получаем список из восьми элементов строкового типа.

# %%
import os
os.mkdir('digitalisierung')

# %%
project_texts = []

# %%
for i in os.listdir('digitalisierung'):
 with open('digitalisierung/' + i) as f:
  textde = f.read()
  project_texts.append(textde)

# %% [markdown]
# Шаг 2: нормализация текстов. После приведения к нижнему регистру и удалению пунктуации выяснилось, что в некоторых словах мелькает нечитаемый символ, который пришлось удалять дополнительно регулярным выражением.

# %%
import string
import re
def normalize(i):
  normalized1 = i.lower().translate(str.maketrans('' , '', string.punctuation))
  normalized2 = re.sub('￾', '', normalized1)
  return normalized2

normalized_project_texts = []
for i in project_texts:
  normalize(i)
  normalized_project_texts.append(normalize(i))

# %%
print(normalized_project_texts[1]) # код для проверки

# %% [markdown]
# Шаг 3: токенизация. Удаление пунктуации, цифр, а также стоп-слов на немецком и английском.

# %%
# !pip install nltk

from nltk.tokenize import word_tokenize, wordpunct_tokenize, sent_tokenize

from nltk import download
download('punkt')
download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('german', 'english')

# %%
def tokenize(i):
  tokenized1 = word_tokenize(i)
  tokenized2 = [word for word in tokenized1 if word not in stop_words and word[0].isalpha()]
  return tokenized2

tokenized_project_texts = []
for i in normalized_project_texts:
  tokenized_project_texts.append(tokenize(i))

# %%
print(type((tokenized_project_texts[2]))) # код для проверки

# %% [markdown]
# Шаг 4: лемматизация токенов при помощи Hanover Tagger (HanTa).

# %%
! pip install HanTa
from HanTa import HanoverTagger as ht

tagger_de = ht.HanoverTagger('morphmodel_ger.pgz')

# %%
# функция для лемматизации списка токенов внутри одного текста:

def lemmatize(token):
    lemma = tagger_de.analyze(token)
    return lemma

# %%
texts_for_vectorizing = [] # сюда будут сохраняться лемматизированные тексты-строки

# %%
# лемматизация списка токенов, превращение результата в строку, сохранение строки в пустой список - для первого текста:

lemmas_tuples1 = []
for token in tokenized_project_texts[0]:
  lemmas_tuples1.append(lemmatize(token))
lemmas_list1 = []
for pair in lemmas_tuples1:
  lemmas_list1.append('_'.join(pair))

lemmas_string1 = ' '.join(lemmas_list1)
print(lemmas_string1)
texts_for_vectorizing.append(lemmas_string1)
# Out:
# Forschungsbeirat_NN wandlungsfähig_ADJ(A) menschzentriert_ADJ(A) Struktur_NN Fabrik_NN Netzwerk_NN Industrie_FM Vorwort_NN zunehmend_ADJ(A) Individualisierung_NN marktbedingen_VV(PP) verstärkt_ADJ(A) Produktinnovation_NN führen_VV(INF) Variantenvielfalt_NN verkürzt_ADJ(A) produktlebenszykl_ADJ(A) produzierend_ADJ(A) unternehmen_VV(INF) bedeuten_VV(FIN) kurzzyklisch_ADJ(A) Produktion_NN neu_ADJ(A) Variante_NN innovativ_ADJ(A) Produkt_NN Kerngeschäft_NN erfolgreich_ADJ(D) realisieren_VV(INF) Fähigkeit_NN rasch_ADJ(D) Veränderung_NN reagieren_VV(INF) wesentlich_ADJ(A) Erfolgsfaktor_NN erreichen_VV(INF) lassen_VV(FIN) Integration_NN Wandlungsfähigkeit_NN unternehmen_VV(INF) bereits_ADV heute_ADV leisten_VV(INF) Technologie_NN Industrie_FM Fabrik_NN Netzwerk_NN zielgerichtet_ADJ(A) Beitrag_NN Erhöhung_NN Wandlungsfähigkeit_NN konkret_ADJ(A) Auswirkung_NN Wandlungsfähigkeit_NN Industrie_FM jedoch_ADV ausreichend_ADJ(D) untersuchen_VV(PP) Interdependenz_NN Industrie_FM Organisation_NN Mitarbeiter_NN hinsichtlich_APPR Wandlungsfähigkeit_NN unternehmen_VV(INF) abschließend_ADJ(D) beschreiben_VV(PP) Rolle_NN Mensch_NN benötigen_VV(FIN) dabei_PROAV besonder_ADJ(A) Aufmerksamkeit_NN Zukunft_NN Arbeit_NN Deutschland_NE Industrieland_NN analysieren_VV(INF) menschzentriert_ADJ(A) Wandlungsfähigkeit_NN Industrie_FM Studie_NN untersuchen_VV(PP) wobei_PWAV Arbeitsgruppe_NN Forschung_NN Innovation_NN Plattform_NN Industrie_FM einbeziehen_VV(PP) werden_VA(FIN) Einbindung_NN Wirtschaft_NN Wissenschaft_NN Politik_NN Form_NN Kamingespräch_NN verschieden_ADJ(A) Experteninterview_NN abschließend_ADJ(A) Workshop_NN Verdeutlichung_NN bisherig_ADJ(A) Defizit_NN Vielzahl_NN Analyse_NN Lösungsmöglichkeit_NN aufzeigen_VV(PP) möchten_VM(FIN) folgend_ADJ(A) präsentieren_VV(INF) anregend_ADJ(A) Lektüre_NN vorliegend_ADJ(A) Studie_NN Erfolg_NN Planung_NN Einführung_NN Umsetzung_NN wandlungsfähig_ADJ(A) menschzentriert_ADJ(A) System_NN Struktur_NN wünschen_VV(FIN) prof_XY Gisela_NE Lanza_FM prof_XY Peter_NE Nyhui_NE Management_NN Summary_NE Studie_NN wandlungsfähig_ADJ(A) menschzentriert_ADJ(A) Struktur_NN Fabrik_NN Netzwerk_NN Industrie_FM liegen_VV(FIN) Leitsatz_NN zugrunde_ADV Wandlungsfähigkeit_NN bleiben_VV(FIN) notwendig_ADJ(D) sowohl_KON heute_ADV Zukunft_NN Wandlungsfähigkeit_NN wettbewerbsfähig_ADJ(A) Eigenschaft_NN Produktionsunternehmen_NN Industrie_FM Wandlungsfähigkeit_NN unterstützen_VV(INF) neu_ADJ(A) Technologie_NN Industrie_FM Wandlungsfähigkeit_NN unternehmen_VV(INF) neu_ADJ(A) Art_FM weisen_VV(FIN) realisieren_VV(PP) menschbezogen_ADJ(A) Wandlungsfähigkeit_NN stehen_VV(FIN) Fokus_NN technisch_ADJ(A) Wandlungsfähigkeit_NN mehr_ADV limitierend_ADJ(A) Faktor_NN stehen_VV(FIN) Mensch_NN Organisation_NN Fokus_NN vorliegend_ADJ(A) Untersuchung_NN Wandlungsfähigkeit_NN Ziel_NN Studie_NN Handlungsfeld_NN Gestaltung_NN wandlungsfähig_ADJ(A) menschzentriert_ADJ(A) Struktur_NN Fabrik_NN Netzwerk_NN Industrie_FM aufzeigen_VV(IZU) Ausgangspunkt_NN werden_VA(FIN) bisherig_ADJ(A) Studie_NN Zukunftsbild_NN zusammenführen_VV(PP) beinhalten_VV(FIN) Charakteristika_NE unternehmen_VV(INF) auszeichnen_VV(FIN) Jahr_NN wettbewerbsfähig_ADJ(D) agieren_VV(INF) beschrieben_ADJ(A) Zukunft_NN hoch_ADJ(A) Wandlungsfähigkeit_NN realisieren_VV(INF) Leitplanke_NN Ausgestaltung_NN notwendig_ADJ(D) Form_NN Hypothese_NN formulieren_VV(PP) Hypothese_NN Wandlungsfähigkeit_NN Mensch_NN Organisation_NN Unternehmenskultur_NN bestimmen_VV(PP) Nutzungsgrad_NN technisch_ADJ(A) Gestaltungsrahmen_NN Hypothese_NN Veränderungsbereitschaft_NN Mitarbeiter_NN i40assistenzsystem_ADJ(A) deutlich_ADJ(D) steigern_VV(PP) Hypothese_NN Systemverständnis_NN Mitarbeiter_NN erfolgsentscheidend_ADJ(D) Hypothese_NN dynamisch_ADJ(A) Organisationsform_NN Kombination_NN Vorteil_NN Funktion_NN Prozessorientierung_NN Hypothese_NN horizontal_ADJ(A) Integration_NN erfordern_VV(FIN) Standard_NN Hypothese_NN Optimalität_NN trotz_APPR Dezentralität_NN erreichbar_ADJ(D) Hypothese_NN Industrie_FM erhöhen_VV(PP) Tran ...

# %%
# ниже - повторение предыдущей операции для последующих семи текстов:

# %%
# для второго текста:
lemmas_tuples2 = []
for token in tokenized_project_texts[1]:
  lemmas_tuples2.append(lemmatize(token))
lemmas_list2 = []
for pair in lemmas_tuples2:
  lemmas_list2.append('_'.join(pair))

lemmas_string2 = ' '.join(lemmas_list2)
print(lemmas_string2)
texts_for_vectorizing.append(lemmas_string2)
# Out:
# Forschungsbeirat_NN themenfelder_ADJ(A) Industrie_FM Forschung_NN Entwicklungsbedarf_NN erfolgreich_ADJ(A) Umsetzung_NN Industrie_FM Einleitung_NN Digitalisierung_NN ermöglichen_VV(FIN) Realisierung_NN Industrie_FM viert_ADJ(A) industriell_ADJ(A) Revolution_NN Umbruch_NN hinsichtlich_APPR neu_ADJ(A) Technologie_NN formen_VV(FIN) Arbeit_NN Unternehmensorganisation_NN Geschäft_NN beziehungsweise_KON erlösmodell_ADJ(A) Wertschöpfungsnetzwerk_NN dynamisch_ADJ(A) digital_ADJ(A) Ökosystem_NN potenzial_ADJ(D) gesellschaftlich_ADJ(D) übergreifend_ADJ(A) Wirkung_NN entfalten_VV(INF) heute_ADV vollständig_ADJ(D) erfassen_VV(INF) lassen_VV(FIN) Einsatz_NN cyberphysisch_ADJ(A) System_NN Cp_NE der_PRELAT umfassend_ADJ(A) Vernetzung_NN Grundlage_NN Wandel_NN Basis_NN lassen_VV(INF) Zulieferung_NN Fertigung_NN Wartung_NN Auslieferung_NN Kundenservice_NN miteinander_ADV verknüpfen_VV(INF) starr_ADJ(A) wertschöpfungskett_ADJ(A) hochflexibl_ADJ(A) Wertschöpfungsnetzwerke_NE verwandeln_VV(INF) Industrie_FM beschreiben_VV(FIN) neu_ADJ(A) Stufe_NN Produktion_NN sowie_KON Organisation_NN Steuerung_NN gesamt_ADJ(A) wertschöpfungskett_ADJ(A) Lebenszyklus_NN Produkt_NN hinweg_APZR intelligent_ADJ(A) Produkt_NN lenken_VV(INF) dabei_PROAV Beispiel_NN aktiv_ADJ(D) Produktionsprozeß_NN Gerät_NN lösen_VV(INF) selbständig_ADJ(D) Aktion_NN legen_VV(INF) nächst_ADJ(A) Arbeitsschritt_NN fest_PTKVZ Mithilfe_NN entstehend_ADJ(A) datenmengen_VV(INF) mittels_APPR fortgeschritten_ADJ(A) Analytik_NE sowie_KON künstlich_ADJ(A) Intelligenz_NN Ki_NE Prozeß_NN Echtzeit_NN analysieren_VV(PP) optimieren_VV(PP) Kriterium_NN beispielsweise_ADV kosten_VV(INF) Verfügbarkeit_NN Ressourcenverbrauch_NN darüber_PROAV hinaus_APZR entstehen_VV(INF) neu_ADJ(A) potenzial_ADJ(A) Konzeption_NN Umsetzung_NN innovativ_ADJ(A) Geschäftsmodell_NN technisch_ADJ(A) Hinsicht_NN daran_PROAV neu_ADJ(D) physisch_ADJ(A) Objekt_NN Papierdokument_NN bisher_ADV sogenannt_ADJ(A) digital_ADJ(A) Zwilling_NN bekommen_VV(INF) Konzept_NN digital_ADJ(A) Zwilling_NN zentral_ADJ(D) anstehend_ADJ(A) Veränderung_NN Zug_NN Digitalisierung_NN Implementierung_NN Industrie_FM anwendungsbezogen_ADJ(A) Studie_NN akademisch_ADJ(A) Literatur_NN begreifen_VV(FIN) unterschiedlich_ADJ(D) gefasst1_CARD nachfolgend_ADJ(A) Zusammenstellung_NN Forschungsbedarf_NN erfolgreich_ADJ(A) Umsetzung_NN Industrie_FM orientieren_VV(INF) Definition_NN stark_ADJ(D) Damerau_NE digital_ADJ(A) Zwilling_NN digital_ADJ(A) Repräsentation_NN aktiv_ADJ(A) spezifisch_ADJ(A) Produkt_NN real_ADJ(A) geraten_VV(FIN) Objekt_NN real_ADJ(A) Maschine_NN Dienstleistung_NN real_ADJ(A) immateriell_ADJ(A) Vermögenswert_NN spezifisch_ADJ(A) Produktservicesystem_NE System_FM Produkt_NN verbunden_ADJ(A) Dienstleistung_NN bestehen_VV(FIN) ausgewählt_ADJ(A) Merkmal_NN Eigenschaft_NN Zustand_NN Verhaltensweise_NN innerhalb_APPR einzeln_ADJ(A) verschieden_ADJ(A) lebenszykl_ADJ(A) hinweg_APZR anhand_APPR Modell_NN Information_NN Datum_NN erfassen_VV(PP) fortschreiten_VV(FIN) Kontext_NN Industrie_FM stellen_VV(FIN) Herausforderung_NN Wirtschaftsstandort_NN Deutschland_NE dar_PTKVZ gelten_VV(FIN) global_ADJ(A) Wettbewerb_NN vorangehen_VV(IZU) eigen_ADJ(A) Rolle_NN Leitmarkt_NN Leitanbieter_NN Industrie_FM festigen_VV(INF) gleichzeitig_ADJ(D) drohen_VV(FIN) Risiko_NN global_ADJ(A) Wettbewerb_NN zurückfallen_VV(IZU) Hintergrund_NN Blick_NN Zukunft_NN deutlich_ADJ(D) digital_ADJ(A) Transformation_NN längst_ADV abschließen_VV(PP) bedürfen_VV(FIN) fundiert_ADJ(A) Analyse_NN sowohl_KON Status_FM Quo_FM bestehend_ADJ(A) Defizit_NN sowie_KON Entwicklungschance_NN Risiko_NN kenntlich_ADJ(D) Wandel_NN gezielt_ADJ(D) erfolgreich_ADJ(D) gestalten_VV(INF) gemeinsam_ADJ(A) Anstrengung_NN stakeholder_ADJ(A) Wirtschaft_NN Wissenschaft_NN Gesellschaft_NN erforderlich_ADJ(D) Forschungsbeirat_NN Plattform_NN Industrie_FM Ziel_NN entscheidend_ADJ(A) Beitrag_NN leisten_VV(INF) bilden_VV(FIN) strategisch_ADJ(A) Beratungsgremium_NN Plattform_NN Industrie_FM aufgeben_VV(FIN) gehören_VV(FIN)  ...

# %%
# для третьего текста:
lemmas_tuples3 = []
for token in tokenized_project_texts[2]:
  lemmas_tuples3.append(lemmatize(token))
lemmas_list3 = []
for pair in lemmas_tuples3:
  lemmas_list3.append('_'.join(pair))
lemmas_string3 = ' '.join(lemmas_list3)
print(lemmas_string3)
texts_for_vectorizing.append(lemmas_string3)
# Out:
# schnell_ADJ(D) Markterfolg_NN Memorandum_NN Forschungsbeirat_NN Plattform_NN Industrie_FM agil_ADJ(A) flexibel_ADJ(A) Innovationssystem_NN Deutschland_NE Memorandum_NN nehmen_VV(FIN) Bezug_NN Innovationssystem_NN Deutschland_NE ganz_ADJ(A) rahmen_VV(FIN) innerhalb_APPR neu_ADJ(A) Innovation_NN Form_NN Produkt_NN verfahren_VV(INF) Dienstleistung_NN Geschäftsmodell_NN entstehen_VV(INF) Memorandum_NN Impuls_NN Weiterentwicklung_NN verstehen_VV(INF) motivieren_VV(PP) Erfahrung_NN Mitglied_NN Forschungsbeirat_NN treiben_VV(PP) digital_ADJ(A) Wandel_NN weltweit_ADJ(D) seit_APPR Jahr_NN anhaltend_ADJ(A) Beschleunigung_NN Forschung_NN Entwicklungsprozeß_NN feststellen_VV(IZU) betreffen_VV(FIN) Entwicklung_NN digital_ADJ(A) Hard_FM Software_NN kommend_ADJ(A) Plattformökonomie_NN kaum_ADV Disziplin_NN Branche_NN hiervon_PROAV ausnehmen_VV(PP) immer_ADV agil_ADJ(A) zunehmend_ADJ(D) interdisziplinär_ADJ(A) Entwicklungsmethode_NN kennzeichnen_VV(INF) Wandel_NN entlang_APPR gesamt_ADJ(A) Innovationskette_NN immer_ADV offensichtlich_ADJ(A) wirken_VV(FIN) Beschleunigung_NN Forschung_NN Entwicklungsprozeß_NN Innovationssystem_NN erfordern_VV(FIN) Weiterentwicklung_NN Trennung_NN Anwendung_NN grundlagenorientiert_ADJ(A) Forschung_NN insbesondere_ADV Kontext_NN obsolet_ADJ(D) ebenso_ADV reichen_VV(FIN) viel_PIAT Jahr_NN vorgedacht_ADJ(A) missionsorientiert_ADJ(A) Forschungsförderung_NN alleine_ADV mehr_ADV daher_PROAV gelten_VV(FIN) eben_ADV Gedanke_NN Innovationssystem_NN gestalten_VV(PP) bestehend_ADJ(A) stärken_VV(INF) anknüpfen_VV(FIN) gehören_VV(FIN) hoch_ADJ(A) Qualität_NN Effektivität_NN deutsch_ADJ(A) Ingenieurwissenschaft_NN Grundlage_NN deutsch_ADJ(A) Sozialpartnerschaft_NN System_FM beruflich_ADJ(A) Bildung_NN viele_PIS mehr_ADV gleichzeitig_ADJ(D) modern_ADJ(A) Innovationssystem_NN ermöglichen_VV(INF) grundlegend_ADJ(A) Erkenntnis_NN Rhythmus_NN wenig_PIAT Woche_NN anwendungsreif_ADJ(A) fortentwickeln_VV(IZU) Souveränität_NN Datum_NN geistig_ADJ(A) Eigentum_NN sichern_VV(INF) somit_ADV bestehen_VV(FIN) neu_ADJ(A) dringlichkeit_ADJ(D) erfolgreich_ADJ(A) deutsch_ADJ(A) Innovationssystem_NN hinsichtlich_APPR Geschwindigkeit_NN Flexibilität_NN agilitäen_VV(FIN) robusthei_VV(FIN) Kooperation_NN Kulturänderung_NN nutzenorientiertheit_ADJ(D) neu_ADJ(A) arbeitsweis_ADJ(A) weiterentwickeln_VV(IZU) zukünftig_ADJ(D) international_ADJ(D) Schritt_NN halten_VV(INF) Status_FM Quo_FM Bestandsaufnahme_NN augenfällig_ADJ(A) Entwicklung_NN ergeben_VV(FIN) Anspruch_NN Vollständigkeit_NN erheben_VV(INF) folgend_ADJ(A) Bild_NN Innovation_NN heute_ADV mehr_ADV je_ADV iterativ_ADJ(A) lernend_ADJ(A) Prozeß_NN demsich_ADJ(D) interdisziplinär_ADJ(A) Gruppe_NN schrittweise_ADJ(D) gesucht_ADJ(A) Lösung_NN nähern_VV(INF) Trend_NN kurz_ADJ(A) innovationszykl_ADJ(A) halten_VV(FIN) weiterhin_ADV volatil_ADJ(A) Markt_NN agil_ADJ(A) Entwicklungsmethode_NN Scrum_FM etc_ADV treiben_VV(PP) Gestaltung_NN Organisation_NN Innovationsprozeß_NN sowohl_KON unternehmen_VV(INF) Forschungseinrichtung_NN immer_ADV komplex_ADJ(A) Entwicklung_NN Alltagsgegenstand_NN beinhalten_VV(FIN) heute_ADV häufig_ADJ(D) speziell_ADJ(A) Knowhow_NE Türklingel_NN Gesichtserkennung_NN Kaffeemaschine_NN Sprachsteuerung_NN häufig_ADJ(D) bleiben_VV(INF) Innovation_NN Deutschland_NE Valley_NE Of_FM death_XY hängen_VV(FIN) erreichen_VV(INF) Markt_NN Vergleich_NN immer_ADV international_ADJ(A) Konkurrenz_NN spät_ADJ(D) niemals_ADV Notwendigkeit_NN kontinuierlich_ADJ(D) Innovation_NN betreiben_VV(INF) Unternehmensgröße_NN hinweg_APZR erkennen_VV(PP) Managementaufgabe_NN sehen_VV(PP) Marktführer_NN bleiben_VV(FIN) immer_ADV unternehmen_VV(INF) versuchen_VV(INF) Innovationsprozeß_NN Unternehmensgründung_NN auslagern_VV(IZU) Startup_FM Neugründung_NN Startin_NN Ausgründung_NN geschehen_VV(FIN) kreativ_ADJ(A) potenzial_ADJ(A) ausschöpfen_VV(IZU) zugleich_ADV Entwicklungsrisiko_NN begrenzen_VV(INF) unternehmen_VV(INF) suchen_VV(INF) örtlich_ADJ(A) thematisch_ADJ(A) Nähe_NN wissenschaftsund_ADJ(D) Forschungsein ...

# %%
# для четвёртого текста:
lemmas_tuples4 = []
for token in tokenized_project_texts[3]:
  lemmas_tuples4.append(lemmatize(token))
lemmas_list4 = []
for pair in lemmas_tuples4:
  lemmas_list4.append('_'.join(pair))
lemmas_string4 = ' '.join(lemmas_list4)
print(lemmas_string4)
texts_for_vectorizing.append(lemmas_string4)
# Out:
# Acatech_FM Studie_NN Industrie_FM Maturity_FM Index_NN digital_ADJ(A) Transformation_NN unternehmen_VV(INF) gestalten_VV(INF) updat_ADJ(A) Günther_NE Schuh_NN rein_ADJ(A) ander_PIAT Roman_NE Dumitrescu_NE Antonio_NE Krug_NN Michael_NE Ten_FM Hompel_NE Hrsg_NN Vorwort_NN unternehmen_VV(INF) stehen_VV(FIN) immer_ADV neu_ADJ(A) Herausforderung_NN traditionell_ADJ(A) Markt_NN Plattform_NN verändern_VV(PP) neu_ADJ(A) Technologie_NN Arbeitsmethode_NN verkürzen_VV(INF) innovationszykl_ADJ(A) Klimawandel_NN Ressourcenknappheit_NN erfordern_VV(FIN) zirkulär_ADJ(A) Wirtschaftsansatz_NN Kompetenz_NN Resilienz_NE Reaktion_NN Anpassungsfähigkeit_NN verstärken_VV(PP) fragen_VV(PP) Wettbewerbsfähigkeit_NN Unternehmen_NN sichern_VV(INF) Industrie_FM werden_VA(FIN) viert_ADJ(A) industriell_ADJ(A) Revolution_NN einläuten_VV(PP) Fabrik_NN Zukunft_NN hypervernetzen_VV(PP) Smart_FM autonom_ADJ(D) bieten_VV(FIN) hoch_ADJ(A) Wandlungsfähigkeit_NN optimal_ADJ(A) Ressourceneinsatz_NN Industrie_FM Deutschland_NE Produktionsstandort_NN fabrikausrüst_ADJ(A) Anbieter_NN Geschäftssoftware_NN erheblich_ADJ(D) profitieren_VV(INF) sowohl_KON Produktivität_NN Erlösseite_NN zugleich_ADV erfordern_VV(FIN) Kollaboration_NN Mensch_NN Maschine_NN erhöht_ADJ(A) Flexibilität_NN Anpassungsfähigkeit_NN bieten_VV(FIN) jedoch_ADV ebenso_ADV Aussicht_NN erfüllend_ADJ(A) gut_ADJ(A) Arbeit_NN Mensch_NN Einsatz_NN digital_ADJ(A) Technologie_NN übergreifend_ADJ(A) Vernetzung_NN Gegenstand_NN geraten_VV(FIN) Maschine_NN Zug_NN Implementierung_NN innovativ_ADJ(A) Industrie_FM leisten_VV(INF) ebenso_ADV Beitrag_NN Verbesserung_NN Reaktionsgeschwindigkeit_NN Stärkung_NN Resilienz_NE unternehmen_VV(INF) unerwartet_ADJ(A) Entwicklung_NN coronakris_ADJ(A) gut_ADJ(D) überwinden_VV(INF) zudem_PROAV vereinfachen_VV(PP) Echtzeitvernetzung_NN betreiben_VV(FIN) Wahrung_NN physisch_ADJ(A) Distanz_NN potenzial_ADJ(D) Industrie_FM unternehmen_VV(INF) letzt_ADJ(A) Jahr_NN immer_ADV mehr_ADV wahrnehmen_VV(PP) unternehmen_VV(INF) sehen_VV(INF) Chance_NN Industrie_FM wettbewerbsvorteilen_VV(FIN) verschaffen_VV(INF) Leitposition_NN erlangen_VV(INF) ausbauen_VV(IZU) Wirtschaft_NN wachsen_VV(FIN) Bereitschaft_NN digital_ADJ(A) Transformation_NN Chance_NN begreifen_VV(INF) allerdings_ADV geben_VV(FIN) Prozent_NN Bitkom_FM Research_FM befragt_ADJ(A) Vorstand_NN unternehmen_VV(INF) Digitalisierung_NN hinterherhinken_VV(PP) klar_ADJ(A) Orientierungshilfe_NN Wirtschaft_NN daher_PROAV fragen_VV(PP) entsprechend_ADJ(D) überwältigend_ADJ(D) Erfolg_NN unser_PPOSAT früh_ADJ(A) Acatech_FM Studie_NN Industrie_FM Maturity_FM Index_NN Jahr_NN viel_PIAT Projekt_NN Thema_NN Industrie_FM aktuell_ADJ(D) wachsend_ADJ(A) Wettbewerbsdruck_NN zunehmend_ADJ(A) Notwendigkeit_NN digital_ADJ(A) Transformation_NN starten_VV(PP) groß_ADJ(A) teil_PTKVZ davon_PROAV scheitern_VV(FIN) jedoch_ADV gründen_VV(FIN) dafür_PROAV Projekt_NN oft_ADV hinreichend_ADJ(A) Beitrag_NN Unternehmensziel_NN leisten_VV(INF) stark_ADJ(D) einzeln_ADJ(A) Technologie_NN fokussieren_VV(PP) groß_ADJ(A) Maßstab_NN anwendbar_ADJ(D) erfolgreich_ADJ(A) Beitrag_NN Wertschöpfung_NN Unternehmensziel_NN daher_PROAV unabdingbar_ADJ(D) einzeln_ADJ(A) Pilotprojekt_NN Unternehmensmaßstab_NN umsetzen_VV(PP) zeitnah_ADJ(D) positiv_ADJ(A) Ergebnis_NN unternehmen_VV(INF) liefern_VV(INF) unser_PPOSAT Erfahrung_NN profitieren_VV(INF) unternehmen_VV(INF) deswegen_PROAV besonder_ADJ(A) Maß_NN Analyse_NN eigen_ADJ(A) individuell_ADJ(A) digital_ADJ(A) Transformation_NN ganzheitlich_ADJ(D) systematisch_ADJ(D) Unternehmensziel_NN ausrichten_VV(PP) strategisch_ADJ(A) Einsatz_NN Industrie_FM Studie_NN schrittweise_ADJ(D) herleiten_VV(PP) erleichtern_VV(PP) Einführung_NN Pilotprojekt_NN Wertschöpfung_NN essenziell_ADJ(A) Scaleup_FM Projekt_NN gesamt_ADJ(A) unternehmen_VV(INF) unternehmen_VV(INF) Erfolg_NN Vorgehensweise_NN glauben_VV(FIN) zunehmend_ADJ(D) positiv_ADJ(A) Erfahrung_NN Industrie_FM spiegeln_VV(FIN) groß_ADJ(A) Interesse_NN unser_PPOSAT bisherig_ADJ(A) Studie_NN wide ...

# %%
# для пятого текста:
lemmas_tuples5 = []
for token in tokenized_project_texts[4]:
  lemmas_tuples5.append(lemmatize(token))
lemmas_list5 = []
for pair in lemmas_tuples5:
  lemmas_list5.append('_'.join(pair))
lemmas_string5 = ' '.join(lemmas_list5)
print(lemmas_string5)
texts_for_vectorizing.append(lemmas_string5)
# Out:
# Acatech_FM Kooperation_NN Industrie_FM Maturity_FM Index_NN betrieblich_ADJ(A) Anwendung_NN aktuell_ADJ(A) Herausforderung_NN Fallbeispiel_NN Entwicklungstrend_NN Günther_NE Schuh_NN rein_ADJ(A) ander_PIAT Roman_NE Dumitrescu_NE Antonio_NE Krug_NN Michael_NE Ten_FM Hompel_NE Hrsg_NN Zusammenfassung_NN Erfahrung_NN drei_CARD Jahr_NN Anwendung_NN Acatech_FM Industrie_FM Maturity_FM Index_NN zeigen_VV(FIN) viert_ADJ(A) industriell_ADJ(A) Revolution_NN Implementierung_NN einzeln_ADJ(A) isoliert_ADJ(A) Prototyp_NN umsetzen_VV(INF) lassen_VV(FIN) deutsch_ADJ(A) produzierend_ADJ(A) Industrie_FM mittlerweile_ADV erkennen_VV(PP) vielmehr_ADV stehen_VV(FIN) heute_ADV Gestaltung_NN systematisch_ADJ(A) Transformationsprogramm_NN Fokus_NN klar_ADJ(A) Mehrwert_NN abzielen_VV(INF) stringent_ADJ(D) strukturieren_VV(PP) Einsatz_NN Acatech_FM Industrie_FM Maturity_FM Index_NN seit_APPR Veröffentlichung_NN Acatech_FM Studie_NN drei_CARD Jahr_NN Industrie_FM Maturity_FM Index_NN praktisch_ADJ(A) Werkzeug_NN strukturieren_VV(FIN) digital_ADJ(A) Transformation_NN erweisen_VV(PP) vielfältig_ADJ(A) Einsatz_NN Index_NN hoch_ADJ(A) Interesse_NN Thema_NN zeigen_VV(FIN) unternehmen_VV(INF) zunehmend_ADJ(D) ganzheitlich_ADJ(D) Industrie_FM auseinandersetzen_VV(INF) Einsatz_NN reichen_VV(FIN) Erstellung_NN systematisch_ADJ(A) Roadmap_NE digital_ADJ(A) Transformation_NN einzeln_ADJ(A) Produktionsstandort_NN standortübergreifend_ADJ(A) Synchronisation_NN global_ADJ(A) Digitalisierungsstrategie_NN weiterhin_ADV lassen_VV(FIN) Index_NN fortschreiten_VV(FIN) digital_ADJ(A) Transformation_NN messen_VV(INF) steuern_VV(INF) sowie_KON technisch_ADJ(A) Du_NE diligencen_VV(FIN) Unternehmenszukauf_NN durchführen_VV(INF) verdeutlichen_VV(FIN) groß_ADJ(A) Mehrwert_NN Anwendung_NN Index_NN Erhebung_NN Industrie_FM Maturity_FM Center_FM zeichnen_VV(FIN) folgend_ADJ(A) Bild_NN Achtzig_NN Prozent_NN untersuchen_VV(FIN) unternehmen_VV(INF) erreichen_VV(FIN) zweit_ADJ(A) sechs_CARD Entwicklungsstufe_NN Konnektivität_NN befinden_VV(FIN) Umsetzung_NN Hausaufgabe_NN erst_ADJ(A) Stufe_NN Industrie_FM sichtbarkeit_ADJ(D) angehen_VV(IZU) lediglich_ADV gering_ADJ(A) Zahl_NN unternehmen_VV(INF) vier_CARD Prozent_NN nächsthöher_ADJ(A) Stufe_NN bereits_ADV erreichen_VV(PP) lassen_VV(INF) Vorreiter_NN beziehungsweise_KON Champions_FM Erhebung_NN bezeichnen_VV(FIN) aktuell_ADJ(A) Handlungsfeld_NN digital_ADJ(A) Volkskrankheit_NN viel_PIAT unternehmen_VV(INF) strukturieren_VV(FIN) Vorgehensweise_NN Acatech_FM Industrie_FM Maturity_FM Index_NN abwenden_VV(PP) abschwächen_VV(PP) hierzu_PROAV gehören_VV(FIN) beispielsweise_ADV Mangel_NN einheitlich_ADJ(A) Standard_NN Maschinensteuerung_NN fragil_ADJ(A) Systemintegration_NN Informationssystem_NN gering_ADJ(A) Bereitschaft_NN abteilungsübergreifend_ADJ(A) Zusammenarbeit_NN sowie_KON mangelnd_ADJ(A) Einbindung_NN Mitarbeiterin_NN Mitarbeiter_NN Veränderung_NN unternehmen_VV(INF) daher_PROAV wichtig_ADJ(D) derzeit_ADV systematisch_ADJ(A) unternehmensweit_ADJ(A) Implementierung_NN übergreifend_ADJ(A) datenplattform_ADJ(A) Beispiel_NN Mithilfe_NN cloudbasiert_ADJ(A) industrialinternetofthingsiotplattform_ADJ(A) fokussieren_VV(INF) ermöglichen_VV(INF) Aggregation_FM Datum_NN divers_ADJ(A) Quelle_NN beispielsweise_ADV betrieblich_ADJ(A) Anwendungssystem_NN Maschinensteuerung_NN Sensorik_NE weiterhin_ADV schaffen_VV(INF) Plattform_NN Rahmenbedingung_NN individuell_ADJ(A) Visualisierung_NN Applikation_NN entwickeln_VV(INF) bisherig_ADJ(A) Anwendung_NN Industrie_FM Maturity_FM Index_NN legen_VV(INF) übergreifend_ADJ(A) akut_ADJ(A) Herausforderung_NN vier_CARD Gestaltungsfeld_NN offen_ADJ(D) Bereich_NN Ressource_NN zählen_VV(FIN) durchgängig_ADJ(A) Informationsbereitstellung_NN entlang_APPR wertschöpfungskett_ADJ(A) itbereich_ADJ(D) Einsatz_NN edg_VV(FIN) Cloudcomputing_FM Auflösung_NN automatisierungspyramid_ADJ(A) organisatorisch_ADJ(A) kulturell_ADJ(A) Sicht_NN Einsatz_NN agil_ADJ(A) Methode_NN Förderung_NN Mitwirkung_NN Belegschaft_NN Einsatz_NN Ind ...

# %%
# для шестого текста:
lemmas_tuples6 = []
for token in tokenized_project_texts[5]:
  lemmas_tuples6.append(lemmatize(token))
lemmas_list6 = []
for pair in lemmas_tuples6:
  lemmas_list6.append('_'.join(pair))
lemmas_string6 = ' '.join(lemmas_list6)
print(lemmas_string6)
texts_for_vectorizing.append(lemmas_string6)
# Out:
# Industrie_FM deutsch_ADJ(A) Industrie_FM Index_NN Studie_NN staufen_VV(INF) Ag_NN staufen_VV(INF) digital_ADJ(D) Neonex_FM Gmbh_NN editorial_ADJ(D) lieben_VV(FIN) Leserin_NN Leser_NN gut_ADJ(A) Index_NN gut_ADJ(A) Wein_NN reifen_VV(FIN) alt_ADJ(A) gelten_VV(FIN) deutsch_ADJ(A) Industrie_FM Index_NN bereits_ADV fünft_ADJ(A) Jahr_NN Folge_NN ermitteln_VV(PP) werden_VA(FIN) somit_ADV viel_PIAT interessant_ADJ(A) Zeitreihe_NN liefern_VV(FIN) enorm_ADJ(A) Dynamik_NN digital_ADJ(A) Transformation_NN konkret_ADJ(D) sichtbar_ADJ(D) ergänzen_VV(PP) zahlreich_ADJ(A) Statement_NN laufen_VV(FIN) Jahr_NN fast_ADV Index_NN befragt_ADJ(A) unternehmen_VV(INF) stellen_VV(FIN) ausdrücklich_ADJ(D) bedanken_VV(INF) möchten_VM(FIN) Studie_NN mittlerweile_ADV spannend_ADJ(A) Abbild_NN jung_ADJ(A) Wirtschaftsgeschichte_NN gewordend_ADJ(A) mögen_VM(FIN) angesichts_APPR Zeitraum_NN bisher_ADV Monat_NN vielleicht_ADV Nummer_NN groß_ADJ(D) lohnen_VV(FIN) Blick_NN zurück_PTKVZ Analyse_NN Studienergebnis_NN anno_APPR deutlich_ADJ(A) Mehrheit_NN unternehmen_VV(INF) verharren_VV(FIN) passiv_ADJ(A) schockstarren_VV(FIN) staunen_VV(FIN) faszinieren_VV(FIN) Konkurrent_NN selbstbewussen_VV(PP) vorn_ADV preschen_VV(INF) Sicht_NN heute_ADV ergänzen_VV(FIN) gedanklich_ADJ(D) entweder_KON positiv_ADJ(D) negativ_ADJ(D) sterben_VV(PP) staunen_VV(INF) heute_ADV immer_ADV davon_PROAV überzeugen_VV(PP) welch_PWAT epochal_ADJ(A) rasend_ADJ(D) schnell_ADJ(D) Phase_NN Veränderung_NN gerade_ADV befinden_VV(FIN) ermitteln_VV(FIN) privat_ADJ(D) Index_NN möglich_ADJ(A) fragen_VV(FIN) wann_PWAV zuletzt_ADV Urlaub_NN Reisebüro_NN buchen_VV(PP) lesen_VV(INF) gedruckt_ADJ(A) Tageszeitung_NN laufen_VV(FIN) Lieblingsserie_NN Ard_NE Netflix_FM laden_VV(FIN) Freund_NN Restaurant_NN Netz_NN wenig_PIAT Sternchen_NN bewerten_VV(PP) klar_ADJ(D) unternehmen_VV(INF) geben_VV(FIN) privat_ADJ(A) digital_ADJ(A) Pionier_NN analog_ADJ(A) nostalgiker_ADJ(A) darüber_PROAV nächst_ADJ(A) Kapitel_NN deutsch_ADJ(A) Industriegeschichte_NN allerdings_ADV begreifen_VV(PP) künstlich_ADJ(A) Intelligenz_NN Machine_NE Learning_FM predictiv_ADJ(A) Analytic_NE prägen_VV(PP) herrschen_VV(FIN) Teilnehmer_NN deutsch_ADJ(A) Industrie_FM Index_NN groß_ADJ(A) Einigkeit_NN Martin_NE Haas_NE ceo_XY Staufenag_NE Studie_NN Hintergrund_NN rahmen_VV(FIN) Studie_NN deutsch_ADJ(A) Industrie_FM Index_NN befragen_VV(FIN) Unternehmensberatung_NN staufen_VV(INF) Ag_NN zusammen_ADV staufen_VV(INF) digital_ADJ(D) Neonex_FM Gmbh_NN insgesamt_ADV unternehmen_VV(INF) Deutschland_NE Thema_NN Industrie_FM Befragung_NN erfolgen_VV(FIN) Jahresmitte_NN gut_ADJ(D) zwei_CARD Drittel_NN befragt_ADJ(A) unternehmen_VV(INF) entstammen_VV(INF) Maschine_NN Anlagenbau_NE Elektro_NE Automobilindustrie_NN Ergebnis_NN Ergebnis_NN Überblick_NN digital_ADJ(A) Transformation_NN Deutschland_NE Industriebetrieb_NN ankommen_VV(PP) konsequent_ADJ(A) Smartfactoryansatz_NE bisher_ADV lediglich_ADV Vorreiter_NN verwirklichen_VV(PP) werden_VA(FIN) erstmals_ADV seit_APPR Erhebung_NN deutsch_ADJ(A) Industrie_FM Index_NN Mehrheit_NN befragt_ADJ(A) unternehmen_VV(INF) praktisch_ADJ(A) Erfahrung_NN Industrie_FM vorweisen_VV(IZU) weit_ADJ(A) Betrieb_NN stehen_VV(FIN) kurz_ADJ(D) davor_PROAV operativ_ADJ(A) Einsatz_NN eintreten_VV(IZU) zehnt_ADJ(A) unternehmen_VV(INF) verweigern_VV(PP) Trend_NN zeigen_VV(FIN) Entwicklung_NN Index_NN seit_APPR Punkt_NN kontinuierlich_ADJ(D) heute_ADV Punkt_NN zulegen_VV(PP) betrachten_VV(PP) Branche_NN stehen_VV(FIN) Elektroindustrie_NN dabei_PROAV Punkt_NN spitz_ADJ(A) folgen_VV(PP) Automobilindustrie_NN Maschine_NN Anlagenbau_NE Punkt_NN bisher_ADV liegen_VV(FIN) Fokus_NN ganz_ADV klar_ADJ(D) eigen_ADJ(A) Haus_NN Produktionstechnik_NN langsam_ADJ(D) indirekt_ADJ(A) Bereich_NN digital_ADJ(A) Transformation_NN erfassen_VV(PP) kommen_VV(FIN) neu_ADJ(A) Produktwelt_NN zögerlich_ADJ(D) Fahrt_NN knapp_ADV viertel_ADJ(A) unternehmen_VV(INF) bereits_ADV Industrie40anwendung_NN Leistungsportfolio_NN entsprechend_ADJ(D) erreichen_VV(PP) erstm ...

# %%
# для седьмого текста:
lemmas_tuples7 = []
for token in tokenized_project_texts[6]:
  lemmas_tuples7.append(lemmatize(token))
lemmas_list7 = []
for pair in lemmas_tuples7:
  lemmas_list7.append('_'.join(pair))
lemmas_string7 = ' '.join(lemmas_list7)
print(lemmas_string7)
texts_for_vectorizing.append(lemmas_string7)
# Out:
# Forschungsbeirat_NN Engineering_FM smart_ADJ(A) Produkt_NN Services_FM Plattform_NN Industrie_FM Studie_NN Michael_NE Abramovici_NE Hrsg_NN Einleitung_NN Durchdringung_NN Industrieprodukt_NN Unternehmensprozeß_NN Organisation_NN Internet_NN Datum_NN Mensch_NN Services_FM Ding_NN Internet_NN Of_FM Everything_FM führen_VV(FIN) letzt_ADJ(A) Jahr_NN viert_ADJ(A) Industrierevolution_NN Industrieunternehmen_NN stehen_VV(FIN) gewaltig_ADJ(A) Transformationsprozeß_NN gänzlich_ADJ(D) neu_ADJ(A) innovationspotenzial_ADJ(A) neu_ADJ(A) profitabel_ADJ(A) Geschäftsmodell_NN ermöglichen_VV(FIN) radikal_ADJ(A) Veränderung_NN bewältigen_VV(INF) eingehend_ADJ(A) potenzial_ADJ(A) ausschöpfen_VV(IZU) müssen_VM(FIN) unternehmen_VV(INF) Vielzahl_NN Herausforderung_NN überwinden_VV(INF) unternehmen_VV(INF) Umsetzung_NN Transformationsprozeß_NN unterstützen_VV(INF) werden_VA(FIN) Deutschland_NE weltweit_ADJ(D) verschieden_ADJ(A) Fachverband_NN Arbeitsgruppe_NN bilden_VV(PP) Vielzahl_NN Studie_NN durchführen_VV(PP) sowie_KON zahlreich_ADJ(A) Forschungsprogramm_NN Projekt_NN initiieren_VV(PP) fördern_VV(PP) Schwerpunkt_NN Aktivität_NN liegen_VV(FIN) Bereich_NN Produktion_NN groß_ADJ(A) stärken_VV(FIN) deutsch_ADJ(A) Industrie_FM zählen_VV(FIN) Entwicklung_NN international_ADJ(D) erfolgreich_ADJ(A) Vermarktung_NN innovativ_ADJ(A) Produkt_NN viel_PIAT Bereich_NN technologieführend_ADJ(D) hoch_ADJ(A) ansehen_VV(INF) genießen_VV(INF) German_NE Engineering_FM bereits_ADV heute_ADV Zukunft_NN zentral_ADJ(A) Bedeutung_NN Standort_NN deutsch_ADJ(A) Industrie_FM international_ADJ(D) angesehen_ADJ(A) qualitätsmerkmal_ADJ(A) Wirtschaftsstandort_NN Deutschland_NE Industrie_FM bieten_VV(FIN) Produktion_NN Produktinnovation_NN enorm_ADJ(A) Verbesserung_NN erfolgspotenzial_ADJ(A) Engineering_FM neu_ADJ(A) Produktgeneration_NN Erfolg_NN deutsch_ADJ(A) Industrie_FM enorm_ADJ(D) Bedeutung_NN gewinnen_VV(INF) neu_ADJ(A) technologisch_ADJ(A) Information_NN Kommunikationstechnik_NN Iktentwicklung_NN profitieren_VV(INF) Meinung_NN viel_PIAT Experte_NN liegen_VV(FIN) meist_PIAT verbesserungspotenzial_ADJ(A) Industrie_FM Produktion_NN hinaus_APZR effektiv_ADJ(A) Engineering_FM neu_ADJ(A) Generation_FM smart_ADJ(A) Produkt_NN Services_FM sowie_KON der_PRELAT Vermarktung_NN Anwendung_NN neu_ADJ(A) Geschäftsmodell_NN bisherig_ADJ(A) Initiative_NN Umfeld_NN Industrie_FM Fokus_NN stehend_ADJ(A) Bereich_NN stellen_VV(FIN) Mittelpunkt_NN vorliegend_ADJ(A) Studie_NN dar_PTKVZ Handlungsbedarf_NN bei_APPRART Engineering_FM Umfeld_NN Industrie_FM werden_VA(FIN) Acatech_FM deutsch_ADJ(A) Akademie_NN Technikwissenschaft_NN bereits_ADV rahmen_VV(FIN) Expertenworkshop_NN erkennen_VV(PP) Publikation_NN Smart_FM Engineering_FM dokumentiert1_CARD Stellenwert_NN engineerings_ADV innerhalb_APPR Industrie_FM genau_ADJ(D) Un_NE tersuchen_VV(INF) sowie_KON Problemschwerpunkt_NN Handlungsbedarf_NN Umfeld_NN ermitteln_VV(FIN) Acatech_FM interdisziplinär_ADJ(A) Arbeitsgruppe_NN Industrie_FM Engineering_FM smart_ADJ(A) Produkt_NN Services_FM gründen_VV(PP) Ergebnis_NN Arbeitsgruppe_NN werden_VA(FIN) Acatech_FM Vorstudie_NN dokumentiert2_CARD Vorstudie_NN beschreiben_VV(FIN) grundlegend_ADJ(A) Charakteristika_NE smart_ADJ(A) Produkt_NN Services_FM ermitteln_VV(PP) erst_ADJ(A) übergeordnet_ADJ(A) Handlungsbedarf_NN Bereich_NN Engineeringprozesse_FM Methode_NN itwerkzeug_ADJ(A) Organisationsstruktur_NN Kompetenz_NN Ergebnis_NN aufbauend_ADJ(D) werden_VA(FIN) rahmen_VV(FIN) vorliegend_ADJ(A) Studie_NN eng_ADJ(D) Zusammenarbeit_NN national_ADJ(A) Plattform_NN Industrie_FM durchführen_VV(PP) bmbf_XY fördern_VV(PP) werden_VA(FIN) detailliert_ADJ(A) operativ_ADJ(A) Forschungsbedarf_NN Engineering_FM smart_ADJ(A) Produkt_NN Services_FM ermitteln_VV(PP) sollen_VM(FIN) Grundlage_NN zukünftig_ADJ(A) Forschungsprogramm_NN verbundforschungsprojekt_ADJ(A) nächst_ADJ(A) fünf_CARD Jahr_NN dienen_VV(INF) Fokus_NN Studie_NN liegen_VV(FIN) Bereich_NN vorgehensmodell_ADJ(A) Methode_NN itwerkzeug_ADJ(A) Informationsmodell_N ...

# %%
# для восьмого текста:
lemmas_tuples8 = []
for token in tokenized_project_texts[7]:
  lemmas_tuples8.append(lemmatize(token))
lemmas_list8 = []
for pair in lemmas_tuples8:
  lemmas_list8.append('_'.join(pair))
lemmas_string8 = ' '.join(lemmas_list8)
print(lemmas_string8)
texts_for_vectorizing.append(lemmas_string8)
# Out:
# Datenland_NN Deutschland_NE deutsch_ADJ(A) Technologiesektor_NN Hardware_NN Servicestandort_NN Executive_NE Summary_NE deutsch_ADJ(A) Technologiesektor_NN durchlaufen_VV(FIN) bemerkenswert_ADJ(A) Evolutionsprozeß_NN wesentlich_ADJ(A) Merkmal_NN gegensätzlich_ADJ(A) Entwicklung_NN beide_PIAT groß_ADJ(A) sektorsegment_ADJ(A) Hardware_NN Software_NN Services_FM unterscheiden_VV(INF) beträchtlich_ADJ(D) Entwicklungsdynamik_NN Hardwareumsatz_NN seit_APPR Jahr_NN stagnieren_VV(INF) Software_NN Services_FM inzwischen_ADV fundamental_ADJ(A) wachstumstreiber_ADJ(D) gesamt_ADJ(A) Technologiebranche_NN Ergebnis_NN vorliegend_ADJ(A) Untersuchung_NN zeigen_VV(FIN) Umsatz_NN deutsch_ADJ(A) Technologiebranche_NN Jahr_NN Prozent_NN fast_ADV Mrd_NN Euro_NE steigen_VV(INF) Techsektor_FM sieben_CARD Prozentpunkt_NN stark_ADJ(D) wachsen_VV(INF) nominal_ADJ(A) Bruttoinlandsprodukt_NN gleich_ADJ(A) Zeitraum_NN beflügeln_VV(PP) neu_ADJ(A) Megatrend_NN nehmen_VV(INF) nächst_ADJ(A) Monat_NN Investition_NN digital_ADJ(A) Wachstumsfeld_NN Konvergenzbereich_NN Technologie_NN Branche_NN maßgeblich_ADJ(D) hierfür_PROAV drei_CARD treiber_ADV Internet_NN Of_FM Things_FM Analytic_NE artificial_ADJ(D) Intelligence_NE sowie_KON neu_ADJ(A) As_FM A_FM Service_NE Geschäftsmodell_NN Xaa_NE innerhalb_APPR Technologiebranche_NN existieren_VV(FIN) ausgeprägt_ADJ(A) global_ADJ(A) Arbeitsteilung_NN Deutschland_NE Beitrag_NN bestehen_VV(FIN) schwerpunktmäßig_ADJ(D) Software_NN Services_FM Digitalisierung_NN unternehmen_VV(INF) Prozeß_NN sowie_KON umsatzstark_ADJ(A) spezialhardwar_ADJ(A) bereits_ADV heute_ADV Techsektor_FM eng_ADJ(D) Branche_NN verbinden_VV(PP) besonders_ADV eng_ADJ(D) Verzahnung_NN Maschinenbau_NN Sektor_NN technologisch_ADJ(A) Kompetenz_NN Deutschland_NE traditionell_ADJ(D) besonders_ADV ausprägen_VV(PP) erheblich_ADJ(A) Zukunftschance_NN liegen_VV(FIN) daher_PROAV Bereich_NN Industrie_FM Einführung_NN Technologieunternehmen_NN Innovationsmotor_NN Standort_NN Deutschland_NE sowie_KON Business_FM enabler_ADJ(A) prozessgestalt_ADJ(A) neu_ADJ(A) digital_ADJ(A) Angebot_NN darüber_PROAV hinaus_APZR Techsektor_FM wesentlich_ADJ(A) Wirtschaftsfaktor_NN Branche_NN stehen_VV(FIN) hierzulande_ADV unternehmen_VV(INF) mehr_ADV Million_NN Arbeitsplatz_NN Umsatz_NN Mrd_NN Euro_NE machen_VV(FIN) bereits_ADV heute_ADV knapp_ADV Prozent_NN deutsch_ADJ(A) Wirtschaftsleistung_NN vergangen_ADJ(A) Jahr_NN deutsch_ADJ(A) Technologiesektor_NN durchaus_ADV ambivalent_ADJ(A) Marktumfeld_NN behaupten_VV(FIN) Seite_NN bieten_VV(FIN) Digitalisierung_NN riesig_ADJ(A) Chance_NN Seite_NN sehen_VV(FIN) zunehmend_ADJ(D) global_ADJ(A) Wettbewerb_NN aussetzen_VV(PP) Folge_NN mitunter_ADV schmerzhaft_ADJ(A) schlussendlich_ADJ(D) erfolgreich_ADJ(D) Evolutionsprozeß_NN Ende_NN stehen_VV(FIN) Fokussierung_NN spezialisieren_VV(FIN) margenstark_ADJ(A) Angebot_NN stark_ADJ(A) Konzentration_NN Sektorsegment_NN Software_NN Services_FM stehen_VV(FIN) deutsch_ADJ(A) Technologiesektor_NN heute_ADV stark_ADJ(D) Verknüpfung_NN Branche_NN Deutschland_NE Zulieferer_NN technologisch_ADJ(A) Komponente_NN Dienst_NN global_ADJ(A) Kontext_NN positionieren_VV(PP) Land_NN fließen_VV(FIN) dienstleistungsström_ADJ(A) besonders_ADV intensiv_ADJ(D) relevant_ADJ(A) treiber_ADV weit_ADJ(A) Entwicklung_NN Branche_NN vorliegend_ADJ(A) Analyse_NN liefern_VV(FIN) passend_ADJ(A) antworten_VV(INF) Grundlage_NN bilden_VV(FIN) detailliert_ADJ(A) makroökonomisch_ADJ(A) Betrachtung_NN zugrunde_ADV liegend_ADJ(A) zahlen_VV(INF) sowie_KON inputoutputanalys_ADJ(A) Deloitte_NE Economic_NE Consulting_NE Technologie_NN Definition_NN Branche_NN Technologiesektor_NN existieren_VV(FIN) allgemein_ADJ(D) anerkannt_ADJ(A) Bzw_NE durchgängig_ADJ(D) genutzt_ADJ(A) Branchendefinition_NN stattdessen_PROAV Branche_NN mal_ADV eng_ADJ(D) mal_ADV breit_ADJ(A) auslegen_VV(PP) Folge_NN variieren_VV(INF) Angabe_NN Marktgröße_NN einschlägig_ADJ(A) Quelle_NN je_ADV zugrunde_ADV liegend_ADJ(A) Definition_NN teil_PTKVZ recht_ADV deutlich_ADJ(D) nachfol ...

# %%
print(len(texts_for_vectorizing[0])) # код для проверки

# %% [markdown]
# Шаг 5: создание векторов текстов и получение частотного списка по модели tf-idf. Использована функция из семинарской тетради (с минимальными изменениями, вектор внутри каждого кортежа преобразуется из числа в строку).

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
tfidf_vectorizer = TfidfVectorizer(ngram_range=(1, 1))

# %%
def tfidfs(texts_for_vectorizing):
    number_of_texts = len(texts_for_vectorizing)
    tfidf_matrix = tfidf_vectorizer.fit_transform(texts_for_vectorizing)
    npm_tfidf = tfidf_matrix.todense()
    list_of_doc_vectors = []
    for index in range(number_of_texts):
        document_vector = npm_tfidf[index]
        list_of_doc_vectors.append(document_vector.tolist())

    tfidfs_for_texts = []
    types = tfidf_vectorizer.get_feature_names_out()
    for index in range(number_of_texts):
        types_tfidf = [(types[ind], str(list_of_doc_vectors[index][0][ind])) for ind in range(len(types))]
        tfidfs_for_texts.append(types_tfidf)

    return tfidfs_for_texts

# %%
print(tfidfs(texts_for_vectorizing)) # код для проверки
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# сортировка полученных значений

sorted_tfidfs = sorted(tfidfs(texts_for_vectorizing)[0], key=lambda tup: tup[1], reverse=True)

# %%
print(len(sorted_tfidfs)) # код для проверки

# %%
# создание пустого списка и добавление в него строковых элементов: "лемма + вектор"

glossar0 = []
for element in sorted_tfidfs:
  glossar0.append(' '.join(element))

# %%
print(glossar0) # код для проверки
# Out:
# ['fin 0.6221122506633039', 'inf 0.5423077636977488', 'pp 0.33372785458323007', 'prozent_nn 0.13163430333932183', 'unternehmen_vv 0.12333420712858502', 'digital_adj 0.09794187036681752', 'industrie_fm 0.09068691700631251', 'neu_adj 0.07073579526492377', 'eigen_adj 0.06354759471553467', 'betrieb_nn 0.06127803776140844', 'befragt_adj 0.05912196416000416', 'transformation_nn 0.054469366899029724', 'predictiv_adj 0.05328866996624428', 'machine_ne 0.049959152992943276', 'learning_fm 0.04948233639722684', 'maschine_nn 0.04662941679739187', 'bereits_adv 0.04460205084967918', 'groß_adj 0.04460205084967918', 'erfahrung_nn 0.04333548118885287', 'additiv_adj 0.042699196337780784', 'losgröße_nn 0.04087567063058995', 'beispielsweise_adv 0.04054731895425381', 'smart_fm 0.04054731895425381', 'technologie_nn 0.04054731895425381', 'maintenance_fm 0.0380633356901745', 'index_nn 0.03743778415096414', 'fast_adv 0.03455795460088997', 'weit_adj 0.03446522111111573', 'fertigung_nn 0.03404335431189358', 'datum_nn 0.03264729012227251', 'gateway_fm 0.031792188268236626', 'produkt_nn 0.030833551782146255', 'branche_nn 0.03041048921569035', 'entwickeln_vv 0.029504240403641097', 'jahr_nn 0.029019813442020006', 'stehen_vv 0.029019813442020006', 'dabei_proav 0.02838312326797766', 'deutsch_adj 0.02838312326797766', 'mehr_adv 0.02838312326797766', 'viel_piat 0.02838312326797766', 'dürfen_vm 0.028040605475140094', 'mehrheit_nn 0.027250447087059967', 'neuronal_adj 0.027250447087059967', 'digitalisierung_nn 0.027234683449514862', 'geschäftsmodell_nn 0.027206075101893754', 'izu 0.027206075101893754', 'prozeß_nn 0.027206075101893754', 'bezeichnung_nn 0.02664433498312214', 'internetplattform_nn 0.02664433498312214', 'staufen_vv 0.02664433498312214', 'gering_adj 0.02635575732026497', 'industriell_adj 0.02635575732026497', 'drittel_nn 0.026276428515557407', 'realität_nn 0.026276428515557407', 'ermitteln_vv 0.025918465950667477', 'derzeit_adv 0.025491459522854632', 'führungskraft_nn 0.025491459522854632', 'liegen_vv 0.024328391372552282', 'nutzen_vv 0.024328391372552282', 'automobilindustrie_nn 0.022942313570569167', 'bisher_adv 0.022942313570569167', 'gerade_adv 0.022942313570569167', 'verfahren_vv 0.022942313570569167', 'vergleichsweise_adv 0.022942313570569167', 'virtuell_adj 0.022942313570569167', 'zeit_nn 0.022942313570569167', 'netz_nn 0.022838001414104695', 'disruption_fm 0.02270870590588331', 'erwartung_nn 0.02270870590588331', 'motiv_nn 0.02270870590588331', 'supply_fm 0.02270870590588331', 'data_ne 0.022695569541262388', 'schon_adv 0.022695569541262388', 'möglichkeit_nn 0.02230102542483959', 'technologisch_adj 0.021764860081515004', 'automatisierung_nn 0.02042601258713615', 'internet_nn 0.02042601258713615', 'klar_adj 0.02042601258713615', 'mitarbeiter_nn 0.02042601258713615', 'zuletzt_adv 0.02042601258713615', 'eher_adv 0.020393167618283706', 'allerdings_adv 0.020273659477126903', 'deutlich_adj 0.020273659477126903', 'geben_vv 0.020273659477126903', 'produktion_nn 0.020273659477126903', 'thema_nn 0.020273659477126903', 'vielfach_adv 0.02015880685051915', 'entwicklung_nn 0.019951121741388755', 'hoch_adj 0.019951121741388755', 'edg_vv 0.01970732138666805', 'punkt_nn 0.01970732138666805', 'rapid_adj 0.01970732138666805', 'zehn_card 0.01970732138666805', 'derjenige_pds 0.01903166784508725', 'glauben_vv 0.01903166784508725', 'produktionstechnik_nn 0.01903166784508725', 'bedeutung_nn 0.01824629352941421', 'bereich_nn 0.01824629352941421', 'künstlich_adj 0.01824629352941421', 'stark_adj 0.01824629352941421', 'verschieden_adj 0.01824629352941421', 'wenig_piat 0.01824629352941421', 'zeigen_vv 0.01824629352941421', 'begeistern_vv 0.018166964724706646', 'deep_ne 0.018166964724706646', 'einblenden_vv 0.018166964724706646', 'langsam_adj 0.018166964724706646', 'etwa_adv 0.01815645563300991', 'lassen_vv 0.01815645563300991', 'zukunft_nn 0.01815645563300991', 'intelligenz_nn 0.018137383401262502', 'business_fm 0.017844021665998244', 'dagegen_proav 0.017844021665998244', 'di ...

# %%
# сортировка элементов глоссария по частям речи: остаются только существительные (nn) и англицизмы (иностранные слова, fm)

glossar_nn = []
glossar_fm = []

for element in glossar0:
  if element.find('_nn') > 0:
    glossar_nn.append(element.split())
  if element.find('_fm') > 0:
      glossar_fm.append(element.split())

glossar = []
glossar.append(glossar_nn)
glossar.append(glossar_fm)

# %%
# результат: частотные списки для немецких существительных и англицизмов (разных частей речи)

glossar_df = pd.DataFrame(glossar).T.rename(columns={0:"german", 1:"english"})
glossar_df[50:100]
# Out:
#                                             german  \
# 50               [studie_nn, 0.016791936377981712]
# 51         [qualifikation_nn, 0.01659310123286187]
# 52             [reaktion_nn, 0.016559422266297395]
# 53                 [zeit_nn, 0.016523726707311163]
# 54  [prozessorientierung_nn, 0.016355475619811686]
# 55   [verantwortlichkeit_nn, 0.016355475619811686]
# 56             [anpassung_nn, 0.01560574189023832]
# 57      [berücksichtigung_nn, 0.01560574189023832]
# 58                 [ebene_nn, 0.01560574189023832]
# 59             [strategie_nn, 0.01560574189023832]
# 60               [kultur_nn, 0.015556032405808004]
# 61            [information_nn, 0.0155287137037168]
# 62           [hochschule_nn, 0.015376606390133296]
# 63                [schuh_nn, 0.015376606390133296]
# 64           [erreichung_nn, 0.015077881531789024]
# 65    [gestaltungsrahmen_nn, 0.014719928057830515]
# 66              [konzept_nn, 0.014711412982468546]
# 67              [element_nn, 0.014687757073165478]
# 68        [voraussetzung_nn, 0.014687757073165478]
# 69        [ausgestaltung_nn, 0.014193790513969195]
# 70           [gestaltung_nn, 0.013894112261220294]
# 71             [abbildung_nn, 0.01387159961659359]
# 72        [unterstützung_nn, 0.013769772256092636]
# 73              [einheit_nn, 0.013707165028899114]
# 74            [leitlinie_nn, 0.013707165028899114]
# 75  [unternehmensbereich_nn, 0.013707165028899114]
# 76            [bewertung_nn, 0.013481894751700271]
# 77               [design_nn, 0.013481894751700271]
# 78              [vorteil_nn, 0.013481894751700271]
# 79        [dezentralität_nn, 0.013084380495849347]
# 80         [unternehmung_nn, 0.013084380495849347]
# 81               [methode_nn, 0.01307681153997204]
# 82          [entwicklung_nn, 0.013063075159631704]
# 83                 [team_nn, 0.013010974637805097]
# 84            [tätigkeit_nn, 0.013010974637805097]
# 85      [handlungsbedarf_nn, 0.012851787439019794]
# 86               [umgang_nn, 0.012851787439019794]
# 87                   [ag_nn, 0.012444825924646404]
# 88            [erfüllung_nn, 0.012444825924646404]
# 89           [produktion_nn, 0.012411431235899528]
# 90            [grundlage_nn, 0.012409921401650119]
# 91   [ablauforganisation_nn, 0.012336448526009201]
# 92         [adressierung_nn, 0.012336448526009201]
# 93        [weiterbildung_nn, 0.012336448526009201]
# 94                [markt_nn, 0.012259510818723788]
# 95          [verankerung_nn, 0.012259510818723788]
# 96            [auswirkung_nn, 0.01193380262194695]
# 97         [kommunikation_nn, 0.01193380262194695]
# 98    [entwicklungsstufe_nn, 0.011828158761640997]
# 99              [kontext_nn, 0.011681347045552496]
#
#                                               english
# 50                [culture_fm, 0.0016355475619811684]
# 51                   [eats_fm, 0.0016355475619811684]
# 52               [fastwork_fm, 0.0016355475619811684]
# 53  [gestaltungsspielraums_fm, 0.0016355475619811684]
# 54                     [go_fm, 0.0016355475619811684]
# 55                   [grow_fm, 0.0016355475619811684]
# 56                 [hesoun_fm, 0.0016355475619811684]
# 57               [hightech_fm, 0.0016355475619811684]
# 58              [inferiore_fm, 0.0016355475619811684]
# 59                [inspire_fm, 0.0016355475619811684]
# 60                   [iots_fm, 0.0016355475619811684]
# 61                  [lanza_fm, 0.0016355475619811684]
# 62                [leasing_fm, 0.0016355475619811684]
# 63        [liefernetzwerks_fm, 0.0016355475619811684]
# 64                    [lmu_fm, 0.0016355475619811684]
# 65       [onthejobtraining_fm, 0.0016355475619811684]
# 66                   [open_fm, 0.0016355475619811684]
# 67                    [our_fm, 0.0016355475619811684]
# 68               [passador_fm, 0.0016355475619811684]
# 69         [plugandproduce_fm, 0.0016355475619811684]
# 70                [rorsted_fm, 0.0016355475619811684]
# 71              [scientist_fm, 0.0016355475619811684]
# 72                  [score_fm, 0.0016355475619811684]
# 73                [softund_fm, 0.0016355475619811684]
# 74               [stammund_fm, 0.0016355475619811684]
# 75                   [stay_fm, 0.0016355475619811684]
# 76                  [storz_fm, 0.0016355475619811684]
# 77           [tragekomfort_fm, 0.0016355475619811684]
# 78                   [turk_fm, 0.0016355475619811684]
# 79              [uncertain_fm, 0.0016355475619811684]
# 80                    [web_fm, 0.0016355475619811684]
# 81                    [win_fm, 0.0016355475619811684]
# 82                 [bitkom_fm, 0.0013707165028899113]
# 83                   [case_fm, 0.0013707165028899113]
# 84         [cloudcomputing_fm, 0.0013707165028899113]
# 85                     [de_fm, 0.0013707165028899113]
# 86                  [facto_fm, 0.0013707165028899113]
# 87              [feedbacks_fm, 0.0013707165028899113]
# 88                     [on_fm, 0.0013707165028899113]
# 89                [startup_fm, 0.0013707165028899113]
# 90                   [tool_fm, 0.0013707165028899113]
# 91        [worklifebalance_fm, 0.0013707165028899113]
# 92              [execution_fm, 0.0011828158761640996]
# 93             [generation_fm, 0.0011828158761640996]
# 94                   [high_fm, 0.0011828158761640996]
# 95               [maturity_fm, 0.0011828158761640996]
# 96                       [a_fm, 0.001037068827053867]
# 97                    [hard_fm, 0.001037068827053867]
# 98              [augmented_fm, 0.0009179848170728424]
# 99               [business_fm, 0.0009179848170728424]
